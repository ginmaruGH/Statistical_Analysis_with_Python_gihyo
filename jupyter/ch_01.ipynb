# %% [markdown]
# # Chapter01 データについて

# %%
import pandas as pd

# %% [markdown]
# - DataFrame
#   - 2次元のデータ構造
# - Series
#   - 1次元のデータ構造

# %%
df = pd.read_csv('../data/ch1_sport_test.csv', index_col='生徒番号')
print(df)
# Out:
#       学年    握力  上体起こし  点数  順位
# 生徒番号
# 1      1  40.2     34  15   4
# 2      1  34.2     14   7  10
# 3      1  28.8     27  11   7
# 4      2  39.0     27  14   5
# 5      2  50.9     32  17   2
# 6      2  36.5     20   9   9
# 7      3  36.6     31  13   6
# 8      3  49.2     37  18   1
# 9      3  26.0     28  10   8
# 10     3  47.4     32  16   3

# %%
df['握力']
# Out:
# 生徒番号
# 1     40.2
# 2     34.2
# 3     28.8
# 4     39.0
# 5     50.9
# 6     36.5
# 7     36.6
# 8     49.2
# 9     26.0
# 10    47.4
# Name: 握力, dtype: float64

# %%
# データの大きさ
df.shape
# Out:
# (10, 5)

# %% [markdown]
# ## 1.2 変数の種類
#
# - 変数の種類
#   - 質的変数
#     - 2値変数
#   - 量的変数
#
# - 尺度水準
#   - 名義尺度
#   - 順序尺度
#   - 間隔尺度
#   - 比例尺度
#
# - 離散型変数
# - 連続型変数
